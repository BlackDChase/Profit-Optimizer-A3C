# %%
"""
Main function
python main.py
#"""
__author__ = 'BlackDChase,MR-TLL'
__version__ = '0.1.0'
# Imports
from TempEnv import TempEnv as ENV
from Agent import GOD
import log

if __name__=="__main__":
    stateSize = 9
    log.debug(f"stateSize = {stateSize}")
    god = GOD(
        maxEpisode=100,
        nAgent=1,
        #debug=True,
        trajectoryLength=25,
        stateSize=stateSize,
        actionSpaceDeviation=5,
        # This means 5*2+1 number of action [-5*2.5, ... 0 , +5*2.5] percent change in price
    )
    log.info("GOD inititated")
    actionSpace = god.getActionSpace()
    log.info(f"Action space: {actionSpace}")
    env = ENV(stateSize,actionSpace)
    log.info("Environment inititated")
    god.giveEnvironment(env)
    log.info("Environment parsed, Boss inititated")
    try:
        god.train()
    except Exception as catch:
        #log.debug(f"Terminaion Trace back {catch.with_traceback()}")
        log.debug(f"Terminated due to {catch}")
        print("Terminated, check log ",log.name)
        raise catch
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\SilentSolitude\anaconda3\lib\site-packages\torch\nn\modules\container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
#  41%|████      | 41/100 [02:15<03:15,  3.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-db68d99de694> in <module>
#      30     log.info("Environment parsed, Boss inititated")
#      31     try:
# ---> 32         god.train()
#      33     except Exception as catch:
#      34         #log.debug(f"Terminaion Trace back {catch.with_traceback()}")
#
# ~\Desktop\Profit-Optimizer-A3C\Profit-Optimizer-A3C\modules\Agent.py in train(self)
#     138
#     139     def train(self):
# --> 140         self.__trainBoss()
#     141         return
#     142
#
# ~\Desktop\Profit-Optimizer-A3C\Profit-Optimizer-A3C\modules\Agent.py in __trainBoss(self)
#     245
#     246         # Remove multiprocessing for @biribiri
# --> 247         self.__bossAgent[0].train()
#     248         if self.debug:
#     249             log.debug(f"Boss00 training started via GOD")
#
# ~\Desktop\Profit-Optimizer-A3C\Profit-Optimizer-A3C\modules\Agent.py in train(self)
#     324             Also what which advantage function are we calling? @Black :: Nstep advantage.
#     325             #"""
# --> 326             self.calculateV_p()
#     327             self.calculateV_tar()
#     328             self.calculateNSTEPAdvantage()
#
# ~\Desktop\Profit-Optimizer-A3C\Profit-Optimizer-A3C\modules\Agent.py in calculateV_p(self)
#     388         for i in range(self.trajectoryLength):
#     389             state=self.trajectoryS[i]
# --> 390             self.vPredicted[i]=self.god._getCriticValue(state)
#     391         return
#     392
#
# ~\Desktop\Profit-Optimizer-A3C\Profit-Optimizer-A3C\modules\Agent.py in _getCriticValue(self, state)
#     192     def _getCriticValue(self,state):
#     193         self._criticSemaphore.acquire()
# --> 194         vVlaue = self.__criticNet.forward(state)
#     195         self._criticSemaphore.release()
#     196         return vVlaue
#
# ~\Desktop\Profit-Optimizer-A3C\Profit-Optimizer-A3C\modules\NeuralNet.py in forward(self, currentState)
#     105         Output for Critic network   : Advantage
#     106         #"""
# --> 107         output = self.hypoThesis(currentState)
#     108         if self.debug:
#     109             log.debug(f"current state for {self.name} : {currentState}")
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\activation.py in forward(self, input)
#     235
#     236     def forward(self, input: Tensor) -> Tensor:
# --> 237         return F.hardtanh(input, self.min_val, self.max_val, self.inplace)
#     238
#     239     def extra_repr(self) -> str:
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in hardtanh(input, min_val, max_val, inplace)
#    1255         result = torch._C._nn.hardtanh_(input, min_val, max_val)
#    1256     else:
# -> 1257         result = torch._C._nn.hardtanh(input, min_val, max_val)
#    1258     return result
#    1259
#
# ~\anaconda3\lib\traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# ~\anaconda3\lib\traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# ~\anaconda3\lib\traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     360                 filename, lineno, name, lookup_line=False, locals=f_locals))
#     361         for filename in fnames:
# --> 362             linecache.checkcache(filename)
#     363         # If immediate lookup was desired, trigger lookups now.
#     364         if lookup_lines:
#
# ~\anaconda3\lib\site-packages\IPython\core\compilerop.py in check_linecache_ipython(*args)
#     155     """
#     156     # First call the original checkcache as intended
# --> 157     linecache._checkcache_ori(*args)
#     158     # Then, update back the cache with our data, so that tracebacks related
#     159     # to our compiled codes can be produced.
#
# ~\anaconda3\lib\linecache.py in checkcache(filename)
#      72             continue   # no-op for files loaded via a __loader__
#      73         try:
# ---> 74             stat = os.stat(fullname)
#      75         except OSError:
#      76             cache.pop(filename, None)
#
# KeyboardInterrupt:
